# %% [markdown]
# # Média e Desvio Padrão com NumPy

# %%
import csv
import numpy as np

# %%
# Faz o carregamento do arquivo csv
dataset = open('./pokemon.csv', encoding='utf-8')
dataset_csv = csv.reader(dataset, delimiter= ',', quotechar = '"')

header = next(dataset_csv)
header_position = {}

for i in range(len(header)):
    header_position[header[i]] = i

weight_posi = header_position['weight_kg']
pokemon_weight_list = []

for line in dataset_csv:
    weight = line[weight_posi]
    if weight != '':
        weight = float(weight)
        pokemon_weight_list.append(weight)

# %%
# Tirando a Média dos pesos
media = np.mean(pokemon_weight_list)
print(media)
# Desvio Padrão do Peso
desvio_padrao = np.std(pokemon_weight_list)
print(desvio_padrao)
# Out:
# 61.3781049936
# 109.284733976
